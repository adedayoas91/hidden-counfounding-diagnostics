# %% [markdown]
# # v2a Edgewise Localization: Aggregate Method Shards
#
# Run this after both method shards finish. It concatenates method-isolated outputs, recomputes method-level BH q-values for the canonical FDR table, and writes `outputs/v2a-RSNs/n25-e9-r16/edge_localization/`.

# %%
from pathlib import Path
import subprocess
import sys

root = next(
    path
    for path in (Path.cwd().resolve(), *Path.cwd().resolve().parents)
    if (path / 'src' / 'markovianity_diagnostic').exists()
)

subprocess.run(
    [
        sys.executable,
        str(root / 'notebooks' / 'real_data' / 'aggregate_v2a_edgewise_localization.py'),
    ],
    cwd=root,
    check=True,
)
