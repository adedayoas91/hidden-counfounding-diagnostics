# %% [markdown]
# # FullCI extension metrics
# Runs the shared simulation grid and preserves inputs plus per-depth adjacencies for all extension analyses.

# %%
from pathlib import Path
import subprocess, sys
root = next(p for p in (Path.cwd().resolve(), *Path.cwd().resolve().parents) if (p / 'src' / 'markovianity_diagnostic').exists())
subprocess.run([sys.executable, str(root / 'notebooks/simulations/run_extension_metrics.py'), '--method', 'fullci'], cwd=root, check=True)
