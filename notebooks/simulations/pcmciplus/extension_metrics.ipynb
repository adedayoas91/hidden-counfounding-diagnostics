# %% [markdown]
# # PCMCI+ extension metrics
# Runs the shared fixed-lag conditioning-depth grid and preserves inputs plus per-depth adjacencies for all extension analyses.

# %%
import subprocess
import sys
from pathlib import Path

root = next(
    path
    for path in (Path.cwd().resolve(), *Path.cwd().resolve().parents)
    if (path / 'src' / 'markovianity_diagnostic').exists()
)
subprocess.run(
    [
        sys.executable,
        str(root / 'notebooks/simulations/run_extension_metrics.py'),
        '--method',
        'pcmciplus',
    ],
    cwd=root,
    check=True,
)
