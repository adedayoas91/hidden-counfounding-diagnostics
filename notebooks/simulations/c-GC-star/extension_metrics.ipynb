# %% [markdown]
# # Fast fcGC extension metrics
# Runs the shared simulation grid and preserves inputs plus per-depth adjacencies for calibration, localization, depth selection, power summaries, and reporting.

# %%
from pathlib import Path
import subprocess, sys
root = next(p for p in (Path.cwd().resolve(), *Path.cwd().resolve().parents) if (p / 'src' / 'markovianity_diagnostic').exists())
subprocess.run([sys.executable, str(root / 'notebooks/simulations/run_extension_metrics.py'), '--method', 'fast_gcstar_fcgc'], cwd=root, check=True)
