# %% [markdown]
# # LPCMCI and SVAR-FCI comparison
#
# Notebook entry point for the method-comparison analysis. The reusable implementation lives in `lpcmci_svarfci_comparison.py`.

# %%
# %run lpcmci_svarfci_comparison.py
