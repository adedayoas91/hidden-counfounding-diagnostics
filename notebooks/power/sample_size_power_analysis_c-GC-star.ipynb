# %% [markdown]
# # Sample-size power analysis: c-GC-star
#
# Runs only the c-GC-star power-analysis shard. Outputs are written to `outputs/power/sample_size_power/by_method/c-GC-star/` so this notebook can run asynchronously with the c-GC shard.

# %%
from pathlib import Path
import subprocess
import sys

root = next(
    path
    for path in (Path.cwd().resolve(), *Path.cwd().resolve().parents)
    if (path / 'src' / 'markovianity_diagnostic').exists()
)

subprocess.run(
    [
        sys.executable,
        str(root / 'notebooks' / 'power' / 'sample_size_power_by_method.py'),
        '--method',
        'c-GC-star',
    ],
    cwd=root,
    check=True,
)
