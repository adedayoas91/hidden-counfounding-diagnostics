# %% [markdown]
# # Runtime scaling: c-GC-star
#
# Runs only the c-GC-star runtime-scaling shard. Outputs are written to `outputs/power/runtime_scaling/by_method/c-GC-star/` so this notebook can run asynchronously with the c-GC shard.

# %%
from pathlib import Path
import subprocess
import sys

root = next(
    path
    for path in (Path.cwd().resolve(), *Path.cwd().resolve().parents)
    if (path / 'src' / 'markovianity_diagnostic').exists()
)

subprocess.run(
    [
        sys.executable,
        str(root / 'notebooks' / 'power' / 'runtime_scaling_by_method.py'),
        '--method',
        'c-GC-star',
    ],
    cwd=root,
    check=True,
)
